# %%
Task 1: Data Cleaning and Preprocessing

Objective:
Clean and preprocess the given raw sentiment dataset using Python and pandas by identifying missing values, removing duplicate records, and standardizing inconsistent data formats.

# %%
1. Load the Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("Data Set For Task/3) Sentiment dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
2.Understand the Dataset

# %%
df.shape
# Out:
# (732, 15)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Text', 'Sentiment', 'Timestamp', 'User',
#        'Platform', 'Hashtags', 'Retweets', 'Likes', 'Country', 'Year', 'Month',
#        'Day', 'Hour'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
3. Identify Missing Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive         44
# Joy              42
# Excitement       32
# Neutral          14
# Contentment      14
#                  ..
# Triumph           1
# Heartwarming      1
# Obstacle          1
# Sympathy          1
# Pressure          1
# Name: count, Length: 279, dtype: int64

# %%
df['Sentiment'].unique()
# Out:
# array([' Positive  ', ' Negative  ', ' Neutral   ', ' Anger        ',
#        ' Fear         ', ' Sadness      ', ' Disgust      ',
#        ' Happiness    ', ' Joy          ', ' Love         ',
#        ' Amusement    ', ' Enjoyment    ', ' Admiration   ',
#        ' Affection    ', ' Awe          ', ' Disappointed ',
#        ' Surprise     ', ' Acceptance   ', ' Adoration    ',
#        ' Anticipation ', ' Bitter       ', ' Calmness     ',
#        ' Confusion    ', ' Excitement   ', ' Kind         ',
#        ' Pride        ', ' Shame        ', ' Confusion ', ' Excitement ',
#        ' Shame ', ' Elation       ', ' Euphoria      ', ' Contentment   ',
#        ' Serenity      ', ' Gratitude     ', ' Hope          ',
#        ' Empowerment   ', ' Compassion    ', ' Tenderness    ',
#        ' Arousal       ', ' Enthusiasm    ', ' Fulfillment  ',
#        ' Reverence     ', ' Compassion', ' Fulfillment   ', ' Reverence ',
# ...

# %%
df['Sentiment'] = df['Sentiment'].str.strip()

# %%
df['Sentiment'].nunique()
# Out:
# 191

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive                45
# Joy                     44
# Excitement              37
# Contentment             19
# Neutral                 18
#                         ..
# Celestial Wonder         1
# Nature's Beauty          1
# Thrilling Journey        1
# Whispers of the Past     1
# Relief                   1
# Name: count, Length: 191, dtype: int64

# %%
df['Platform'].value_counts()
# Out:
# Platform
# Instagram     258
# Facebook      231
# Twitter       128
# Twitter       115
# Name: count, dtype: int64

# %%
df['Platform'] = df['Platform'].str.strip()

# %%
df['Platform'].value_counts()
# Out:
# Platform
# Instagram    258
# Twitter      243
# Facebook     231
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# USA           59
# USA           55
# UK            49
# Canada        44
# Australia     41
#               ..
# Ireland        1
# Scotland       1
# Kenya          1
# Jamaica        1
# Thailand       1
# Name: count, Length: 115, dtype: int64

# %%
df['Country'] = df['Country'].str.strip()

# %%
df['Country'].value_counts()
# Out:
# Country
# USA               188
# UK                143
# Canada            135
# Australia          75
# India              70
# Brazil             17
# France             16
# Japan              15
# Germany            14
# Italy              11
# Spain               6
# South Africa        6
# Greece              5
# Netherlands         4
# Switzerland         3
# Sweden              2
# Portugal            2
# Austria             2
# Belgium             2
# Denmark             2
# Czech Republic      2
# Jordan              1
# Peru                1
# Maldives            1
# China               1
# Cambodia            1
# Norway              1
# Colombia            1
# Ireland             1
# Jamaica             1
# Kenya               1
# Scotland            1
# Thailand            1
# Name: count, dtype: int64

# %%
df['Text'].head(10)
# Out:
# 0     Enjoying a beautiful day at the park!        ...
# 1     Traffic was terrible this morning.           ...
# 2     Just finished an amazing workout! 💪          ...
# 3     Excited about the upcoming weekend getaway!  ...
# 4     Trying out a new recipe for dinner tonight.  ...
# 5     Feeling grateful for the little things in lif...
# 6     Rainy days call for cozy blankets and hot coc...
# 7     The new movie release is a must-watch!       ...
# 8     Political discussions heating up on the timel...
# 9     Missing summer vibes and beach days.         ...
# Name: Text, dtype: object

# %%
df['Timestamp'].head()
# Out:
# 0    2023-01-15 12:30:00
# 1    2023-01-15 08:45:00
# 2    2023-01-15 15:45:00
# 3    2023-01-15 18:20:00
# 4    2023-01-15 19:55:00
# Name: Timestamp, dtype: object

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df['Timestamp'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['User'].value_counts().head(10)
# Out:
# User
# RainNurturer        3
# PeakConqueror       3
# WindWhisperer       3
# CarnivalDreamer     3
# DawnGardener        3
# WinterWarmth        3
# Stargazer           2
# NatureAdmirer       2
# SkyArtist           2
# RiverNavigator      2
# Name: count, dtype: int64

# %%
df['Hashtags'].head(10)
# Out:
# 0     #Nature #Park
# 1     #Traffic #Morning
# 2     #Fitness #Workout
# 3     #Travel #Adventure
# 4     #Cooking #Food
# 5       #Gratitude #PositiveVibes
# 6     #RainyDays #Cozy
# 7      #MovieNight #MustWatch
# 8      #Politics #Debate
# 9      #Summer #BeachDays
# Name: Hashtags, dtype: object

# %%
df['Hashtags'] = df['Hashtags'].str.strip()

# %%
df['Retweets'].describe()
# Out:
# count    732.000000
# mean      21.508197
# std        7.061286
# min        5.000000
# 25%       17.750000
# 50%       22.000000
# 75%       25.000000
# max       40.000000
# Name: Retweets, dtype: float64

# %%
df['Likes'].describe()
# Out:
# count    732.000000
# mean      42.901639
# std       14.089848
# min       10.000000
# 25%       34.750000
# 50%       43.000000
# 75%       50.000000
# max       80.000000
# Name: Likes, dtype: float64

# %%
df[['Year', 'Month', 'Day', 'Hour']].describe()
# Out:
#               Year       Month         Day        Hour
# count   732.000000  732.000000  732.000000  732.000000
# mean   2020.471311    6.122951   15.497268   15.521858
# std       2.802285    3.411763    8.474553    4.113414
# min    2010.000000    1.000000    1.000000    0.000000
# 25%    2019.000000    3.000000    9.000000   13.000000
# 50%    2021.000000    6.000000   15.000000   16.000000
# 75%    2023.000000    9.000000   22.000000   19.000000
# max    2023.000000   12.000000   31.000000   23.000000

# %%
df[['Timestamp', 'Year', 'Month', 'Day', 'Hour']].head(10)
# Out:
#             Timestamp  Year  Month  Day  Hour
# 0 2023-01-15 12:30:00  2023      1   15    12
# 1 2023-01-15 08:45:00  2023      1   15     8
# 2 2023-01-15 15:45:00  2023      1   15    15
# 3 2023-01-15 18:20:00  2023      1   15    18
# 4 2023-01-15 19:55:00  2023      1   15    19
# 5 2023-01-16 09:10:00  2023      1   16     9
# 6 2023-01-16 14:45:00  2023      1   16    14
# 7 2023-01-16 19:30:00  2023      1   16    19
# 8 2023-01-17 08:00:00  2023      1   17     8
# 9 2023-01-17 12:20:00  2023      1   17    12

# %%
df[['Retweets', 'Likes']].boxplot()
# Out:
# <Axes: >

# %%
df[['Retweets', 'Likes']].quantile([0.25, 0.75])
# Out:
#       Retweets  Likes
# 0.25     17.75  34.75
# 0.75     25.00  50.00

# %%
Q1 = df[['Retweets', 'Likes']].quantile(0.25)
Q3 = df[['Retweets', 'Likes']].quantile(0.75)

IQR = Q3 - Q1

outliers = ((df[['Retweets', 'Likes']] < (Q1 - 1.5 * IQR)) |
            (df[['Retweets', 'Likes']] > (Q3 + 1.5 * IQR))).sum()

outliers
# Out:
# Retweets    18
# Likes       18
# dtype: int64

# %%
df[['Unnamed: 0.1', 'Unnamed: 0']].head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
# 5             5           5
# 6             6           6
# 7             7           7
# 8             8           8
# 9             9           9

# %%
df = df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])

# %%
df.columns
# Out:
# Index(['Text', 'Sentiment', 'Timestamp', 'User', 'Platform', 'Hashtags',
#        'Retweets', 'Likes', 'Country', 'Year', 'Month', 'Day', 'Hour'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       732 non-null    object
#  1   Sentiment  732 non-null    object
#  2   Timestamp  732 non-null    datetime64[ns]
#  3   User       732 non-null    object
#  4   Platform   732 non-null    object
#  5   Hashtags   732 non-null    object
#  6   Retweets   732 non-null    float64
#  7   Likes      732 non-null    float64
#  8   Country    732 non-null    object
#  9   Year       732 non-null    int64
#  10  Month      732 non-null    int64
#  11  Day        732 non-null    int64
#  12  Hour       732 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(6)
# memory usage: 74.5+ KB

# %%
df.to_csv("cleaned_sentiment_dataset.csv", index=False)

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'cleaned_sentiment_dataset.csv',
#  'Data Set For Task',
#  'Task_1_Data_Cleaning_Preprocessing.ipynb']
